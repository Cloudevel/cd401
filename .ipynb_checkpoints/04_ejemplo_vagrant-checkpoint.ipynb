# %% [markdown]
# # Virtualización en un entorno GNU/Linux.

# %% [markdown]
# ## Conceptos básicos de virtualización.

# %%
lscpu | grep Virtualization

# %% [markdown]
# ## Virtualbox

# %%
sudo yum groupinstall 'Development Tools' -y

# %%
sudo yum install SDL kernel-devel kernel-headers dkms kvm libvirt -y
# Out:
# Loaded plugins: fastestmirror
# Loading mirror speeds from cached hostfile
#  * base: mirror.wdc1.us.leaseweb.net
#  * epel: mirror.grid.uchicago.edu
#  * extras: mirror.dal10.us.leaseweb.net
#  * updates: mirrors.advancedhosters.com
# Package SDL-1.2.15-14.el7.x86_64 already installed and latest version
# Package kernel-devel-3.10.0-862.2.3.el7.x86_64 already installed and latest version
# Package kernel-headers-3.10.0-862.2.3.el7.x86_64 already installed and latest version
# Package dkms-2.5.0-2.20180306gitb1b9033.el7.noarch already installed and latest version
# Resolving Dependencies
# --> Running transaction check
# ---> Package libvirt.x86_64 0:3.9.0-14.el7_5.4 will be installed
# --> Processing Dependency: libvirt-libs = 3.9.0-14.el7_5.4 for package: libvirt-3.9.0-14.el7_5.4.x86_64
# --> Processing Dependency: libvirt-daemon-driver-storage = 3.9.0-14.el7_5.4 for package: libvirt-3.9.0-14.el7_5.4.x86_64
# --> Processing Dependency: libvirt-daemon-driver-secret = 3.9.0-14.el7_5.4 for package: libvirt-3.9.0-14.el7_5.4.x86_64
# --> Processing Dependency: libvirt-daemon-driver-qemu = 3.9.0-14.el7_5.4 for package: libvirt-3.9.0-14.el7_5.4.x86_64
# --> Processing Dependency: libvirt-daemon-driver-nwfilter = 3.9.0-14.el7_5.4 for package: libvirt-3.9.0-14.el7_5.4.x86_64
# --> Processing Dependency: libvirt-daemon-driver-nodedev = 3.9.0-14.el7_5.4 for package: libvirt-3.9.0-14.el7_5.4.x86_64
# --> Processing Dependency: libvirt-daemon-driver-network = 3.9.0-14.el7_5.4 for package: libvirt-3.9.0-14.el7_5.4.x86_64
# --> Processing Dependency: libvirt-daemon-driver-lxc = 3.9.0-14.el7_5.4 for package: libvirt-3.9.0-14.el7_5.4.x86_64
# --> Processing Dependency: libvirt-daemon-driver-interface = 3.9.0-14.el7_5.4 for package: libvirt-3.9.0-14.el7_5.4.x86_64
# --> Processing Dependency: libvirt-daemon-config-nwfilter = 3.9.0-14.el7_5.4 for package: libvirt-3.9.0-14.el7_5.4.x86_64
# --> Processing Dependency: libvirt-daemon-config-network = 3.9.0-14.el7_5.4 for package: libvirt-3.9.0-14.el7_5.4.x86_64
# --> Processing Dependency: libvirt-daemon = 3.9.0-14.el7_5.4 for package: libvirt-3.9.0-14.el7_5.4.x86_64
# --> Processing Dependency: libvirt-client = 3.9.0-14.el7_5.4 for package: libvirt-3.9.0-14.el7_5.4.x86_64
# ---> Package qemu-system-x86.x86_64 2:2.0.0-1.el7.6 will be installed
# --> Processing Dependency: qemu-common = 2:2.0.0-1.el7.6 for package: 2:qemu-system-x86-2.0.0-1.el7.6.x86_64
# --> Processing Dependency: sgabios-bin >= 1.7.2.2-5 for package: 2:qemu-system-x86-2.0.0-1.el7.6.x86_64
# --> Processing Dependency: ipxe-roms-qemu for package: 2:qemu-system-x86-2.0.0-1.el7.6.x86_64
# --> Processing Dependency: libibverbs.so.1(IBVERBS_1.0)(64bit) for package: 2:qemu-system-x86-2.0.0-1.el7.6.x86_64
# --> Processing Dependency: libibverbs.so.1(IBVERBS_1.1)(64bit) for package: 2:qemu-system-x86-2.0.0-1.el7.6.x86_64
# --> Processing Dependency: libpulse.so.0(PULSE_0)(64bit) for package: 2:qemu-system-x86-2.0.0-1.el7.6.x86_64
# --> Processing Dependency: librdmacm.so.1(RDMACM_1.0)(64bit) for package: 2:qemu-system-x86-2.0.0-1.el7.6.x86_64
# --> Processing Dependency: libspice-server.so.1(SPICE_SERVER_0.10.0)(64bit) for package: 2:qemu-system-x86-2.0.0-1.el7.6.x86_64
# --> Processing Dependency: libspice-server.so.1(SPICE_SERVER_0.10.1)(64bit) for package: 2:qemu-system-x86-2.0.0-1.el7.6.x86_64
# --> Processing Dependency: libspice-server.so.1(SPICE_SERVER_0.10.2)(64bit) for package: 2:qemu-system-x86-2.0.0-1.el7.6.x86_64
# --> Processing Dependency: libspice-server.so.1(SPICE_SERVER_0.10.3)(64bit) for package: 2:qemu-system-x86-2.0.0-1.el7.6.x86_64
# --> Processing Dependency: libspice-server.so.1(SPICE_SERVER_0.10.4)(64bit) for package: 2:qemu-system-x86-2.0.0-1.el7.6.x86_64
# --> Processing Dependency: libspice-server.so.1(SPICE_SERVER_0.11.2)(64bit) for package: 2:qemu-system-x86-2.0.0-1.el7.6.x86_64
# --> Processing Dependency: libspice-server.so.1(SPICE_SERVER_0.12.2)(64bit) for package: 2:qemu-system-x86-2.0.0-1.el7.6.x86_64
# --> Processing Dependency: libspice-server.so.1(SPICE_SERVER_0.12.3)(64bit) for package: 2:qemu-system-x86-2.0.0-1.el7.6.x86_64
# --> Processing Dependency: libspice-server.so.1(SPICE_SERVER_0.12.4)(64bit) for package: 2:qemu-system-x86-2.0.0-1.el7.6.x86_64
# --> Processing Dependency: libspice-server.so.1(SPICE_SERVER_0.6.0)(64bit) for package: 2:qemu-system-x86-2.0.0-1.el7.6.x86_64
# --> Processing Dependency: libspice-server.so.1(SPICE_SERVER_0.8.1)(64bit) for package: 2:qemu-system-x86-2.0.0-1.el7.6.x86_64
# --> Processing Dependency: libspice-server.so.1(SPICE_SERVER_0.8.2)(64bit) for package: 2:qemu-system-x86-2.0.0-1.el7.6.x86_64
# --> Processing Dependency: libspice-server.so.1(SPICE_SERVER_0.8.3)(64bit) for package: 2:qemu-system-x86-2.0.0-1.el7.6.x86_64
# --> Processing Dependency: seavgabios-bin for package: 2:qemu-system-x86-2.0.0-1.el7.6.x86_64
# --> Processing Dependency: libatk-1.0.so.0()(64bit) for package: 2:qemu-system-x86-2.0.0-1.el7.6.x86_64
# --> Processing Dependency: libbluetooth.so.3()(64bit) for package: 2:qemu-system-x86-2.0.0-1.el7.6.x86_64
# --> Processing Dependency: libbrlapi.so.0.6()(64bit) for package: 2:qemu-system-x86-2.0.0-1.el7.6.x86_64
# --> Processing Dependency: libcairo-gobject.so.2()(64bit) for package: 2:qemu-system-x86-2.0.0-1.el7.6.x86_64
# --> Processing Dependency: libcairo.so.2()(64bit) for package: 2:qemu-system-x86-2.0.0-1.el7.6.x86_64
# --> Processing Dependency: libgdk-3.so.0()(64bit) for package: 2:qemu-system-x86-2.0.0-1.el7.6.x86_64
# --> Processing Dependency: libgdk_pixbuf-2.0.so.0()(64bit) for package: 2:qemu-system-x86-2.0.0-1.el7.6.x86_64
# --> Processing Dependency: libgtk-3.so.0()(64bit) for package: 2:qemu-system-x86-2.0.0-1.el7.6.x86_64
# --> Processing Dependency: libibverbs.so.1()(64bit) for package: 2:qemu-system-x86-2.0.0-1.el7.6.x86_64
# --> Processing Dependency: libiscsi.so.2()(64bit) for package: 2:qemu-system-x86-2.0.0-1.el7.6.x86_64
# --> Processing Dependency: libpango-1.0.so.0()(64bit) for package: 2:qemu-system-x86-2.0.0-1.el7.6.x86_64
# --> Processing Dependency: libpangocairo-1.0.so.0()(64bit) for package: 2:qemu-system-x86-2.0.0-1.el7.6.x86_64
# --> Processing Dependency: libpixman-1.so.0()(64bit) for package: 2:qemu-system-x86-2.0.0-1.el7.6.x86_64
# --> Processing Dependency: libpulse.so.0()(64bit) for package: 2:qemu-system-x86-2.0.0-1.el7.6.x86_64
# --> Processing Dependency: librdmacm.so.1()(64bit) for package: 2:qemu-system-x86-2.0.0-1.el7.6.x86_64
# --> Processing Dependency: libspice-server.so.1()(64bit) for package: 2:qemu-system-x86-2.0.0-1.el7.6.x86_64
# --> Processing Dependency: libusb-1.0.so.0()(64bit) for package: 2:qemu-system-x86-2.0.0-1.el7.6.x86_64
# --> Processing Dependency: libusbredirparser.so.1()(64bit) for package: 2:qemu-system-x86-2.0.0-1.el7.6.x86_64
# --> Processing Dependency: libvte2_90.so.9()(64bit) for package: 2:qemu-system-x86-2.0.0-1.el7.6.x86_64
# --> Running transaction check
# ---> Package atk.x86_64 0:2.22.0-3.el7 will be installed
# ---> Package bluez-libs.x86_64 0:5.44-4.el7_4 will be installed
# ---> Package brlapi.x86_64 0:0.6.0-16.el7 will be installed
# --> Processing Dependency: brltty = 4.5-16.el7 for package: brlapi-0.6.0-16.el7.x86_64
# --> Processing Dependency: libXtst.so.6()(64bit) for package: brlapi-0.6.0-16.el7.x86_64
# ---> Package cairo.x86_64 0:1.14.8-2.el7 will be installed
# --> Processing Dependency: libEGL.so.1()(64bit) for package: cairo-1.14.8-2.el7.x86_64
# ---> Package cairo-gobject.x86_64 0:1.14.8-2.el7 will be installed
# ---> Package gdk-pixbuf2.x86_64 0:2.36.5-1.el7 will be installed
# --> Processing Dependency: libtiff.so.5(LIBTIFF_4.0)(64bit) for package: gdk-pixbuf2-2.36.5-1.el7.x86_64
# --> Processing Dependency: libtiff.so.5()(64bit) for package: gdk-pixbuf2-2.36.5-1.el7.x86_64
# --> Processing Dependency: libjasper.so.1()(64bit) for package: gdk-pixbuf2-2.36.5-1.el7.x86_64
# ---> Package gtk3.x86_64 0:3.22.26-4.el7_5 will be installed
# --> Processing Dependency: libwayland-cursor(x86-64) >= 1.9.91 for package: gtk3-3.22.26-4.el7_5.x86_64
# --> Processing Dependency: libwayland-client(x86-64) >= 1.9.91 for package: gtk3-3.22.26-4.el7_5.x86_64
# --> Processing Dependency: libepoxy(x86-64) >= 1.0 for package: gtk3-3.22.26-4.el7_5.x86_64
# --> Processing Dependency: libXrandr(x86-64) >= 1.5.0 for package: gtk3-3.22.26-4.el7_5.x86_64
# --> Processing Dependency: libxkbcommon.so.0(V_0.5.0)(64bit) for package: gtk3-3.22.26-4.el7_5.x86_64
# --> Processing Dependency: hicolor-icon-theme for package: gtk3-3.22.26-4.el7_5.x86_64
# --> Processing Dependency: gtk-update-icon-cache for package: gtk3-3.22.26-4.el7_5.x86_64
# --> Processing Dependency: dconf(x86-64) for package: gtk3-3.22.26-4.el7_5.x86_64
# --> Processing Dependency: adwaita-icon-theme for package: gtk3-3.22.26-4.el7_5.x86_64
# --> Processing Dependency: libxkbcommon.so.0()(64bit) for package: gtk3-3.22.26-4.el7_5.x86_64
# --> Processing Dependency: libwayland-egl.so.1()(64bit) for package: gtk3-3.22.26-4.el7_5.x86_64
# --> Processing Dependency: libwayland-cursor.so.0()(64bit) for package: gtk3-3.22.26-4.el7_5.x86_64
# --> Processing Dependency: libwayland-client.so.0()(64bit) for package: gtk3-3.22.26-4.el7_5.x86_64
# --> Processing Dependency: librest-0.7.so.0()(64bit) for package: gtk3-3.22.26-4.el7_5.x86_64
# --> Processing Dependency: libjson-glib-1.0.so.0()(64bit) for package: gtk3-3.22.26-4.el7_5.x86_64
# --> Processing Dependency: libepoxy.so.0()(64bit) for package: gtk3-3.22.26-4.el7_5.x86_64
# --> Processing Dependency: libcups.so.2()(64bit) for package: gtk3-3.22.26-4.el7_5.x86_64
# --> Processing Dependency: libcolord.so.2()(64bit) for package: gtk3-3.22.26-4.el7_5.x86_64
# --> Processing Dependency: libatk-bridge-2.0.so.0()(64bit) for package: gtk3-3.22.26-4.el7_5.x86_64
# --> Processing Dependency: libXrandr.so.2()(64bit) for package: gtk3-3.22.26-4.el7_5.x86_64
# --> Processing Dependency: libXi.so.6()(64bit) for package: gtk3-3.22.26-4.el7_5.x86_64
# --> Processing Dependency: libXcomposite.so.1()(64bit) for package: gtk3-3.22.26-4.el7_5.x86_64
# ---> Package ipxe-roms-qemu.noarch 0:20170123-1.git4e85b27.el7_4.1 will be installed
# ---> Package libibverbs.x86_64 0:15-7.el7_5 will be installed
# --> Processing Dependency: rdma-core(x86-64) = 15-7.el7_5 for package: libibverbs-15-7.el7_5.x86_64
# ---> Package libiscsi.x86_64 0:1.9.0-7.el7 will be installed
# ---> Package librdmacm.x86_64 0:15-7.el7_5 will be installed
# ---> Package libusbx.x86_64 0:1.0.21-1.el7 will be installed
# ---> Package libvirt-client.x86_64 0:3.9.0-14.el7_5.4 will be installed
# --> Processing Dependency: gnutls-utils for package: libvirt-client-3.9.0-14.el7_5.4.x86_64
# --> Processing Dependency: libyajl.so.2()(64bit) for package: libvirt-client-3.9.0-14.el7_5.4.x86_64
# ---> Package libvirt-daemon.x86_64 0:3.9.0-14.el7_5.4 will be installed
# --> Processing Dependency: numad for package: libvirt-daemon-3.9.0-14.el7_5.4.x86_64
# --> Processing Dependency: libcgroup for package: libvirt-daemon-3.9.0-14.el7_5.4.x86_64
# ---> Package libvirt-daemon-config-network.x86_64 0:3.9.0-14.el7_5.4 will be installed
# ---> Package libvirt-daemon-config-nwfilter.x86_64 0:3.9.0-14.el7_5.4 will be installed
# ---> Package libvirt-daemon-driver-interface.x86_64 0:3.9.0-14.el7_5.4 will be installed
# --> Processing Dependency: netcf-libs >= 0.2.2 for package: libvirt-daemon-driver-interface-3.9.0-14.el7_5.4.x86_64
# --> Processing Dependency: libnetcf.so.1(NETCF_1.4.0)(64bit) for package: libvirt-daemon-driver-interface-3.9.0-14.el7_5.4.x86_64
# --> Processing Dependency: libnetcf.so.1(NETCF_1.3.0)(64bit) for package: libvirt-daemon-driver-interface-3.9.0-14.el7_5.4.x86_64
# --> Processing Dependency: libnetcf.so.1(NETCF_1.2.0)(64bit) for package: libvirt-daemon-driver-interface-3.9.0-14.el7_5.4.x86_64
# --> Processing Dependency: libnetcf.so.1(NETCF_1.0.0)(64bit) for package: libvirt-daemon-driver-interface-3.9.0-14.el7_5.4.x86_64
# --> Processing Dependency: libnetcf.so.1()(64bit) for package: libvirt-daemon-driver-interface-3.9.0-14.el7_5.4.x86_64
# ---> Package libvirt-daemon-driver-lxc.x86_64 0:3.9.0-14.el7_5.4 will be installed
# --> Processing Dependency: libfuse.so.2(FUSE_2.8)(64bit) for package: libvirt-daemon-driver-lxc-3.9.0-14.el7_5.4.x86_64
# --> Processing Dependency: libfuse.so.2(FUSE_2.6)(64bit) for package: libvirt-daemon-driver-lxc-3.9.0-14.el7_5.4.x86_64
# --> Processing Dependency: libfuse.so.2(FUSE_2.5)(64bit) for package: libvirt-daemon-driver-lxc-3.9.0-14.el7_5.4.x86_64
# --> Processing Dependency: libfuse.so.2(FUSE_2.2)(64bit) for package: libvirt-daemon-driver-lxc-3.9.0-14.el7_5.4.x86_64
# --> Processing Dependency: libfuse.so.2()(64bit) for package: libvirt-daemon-driver-lxc-3.9.0-14.el7_5.4.x86_64
# ---> Package libvirt-daemon-driver-network.x86_64 0:3.9.0-14.el7_5.4 will be installed
# --> Processing Dependency: dnsmasq >= 2.41 for package: libvirt-daemon-driver-network-3.9.0-14.el7_5.4.x86_64
# --> Processing Dependency: radvd for package: libvirt-daemon-driver-network-3.9.0-14.el7_5.4.x86_64
# ---> Package libvirt-daemon-driver-nodedev.x86_64 0:3.9.0-14.el7_5.4 will be installed
# ---> Package libvirt-daemon-driver-nwfilter.x86_64 0:3.9.0-14.el7_5.4 will be installed
# --> Processing Dependency: libpcap.so.1()(64bit) for package: libvirt-daemon-driver-nwfilter-3.9.0-14.el7_5.4.x86_64
# ---> Package libvirt-daemon-driver-qemu.x86_64 0:3.9.0-14.el7_5.4 will be installed
# --> Processing Dependency: libvirt-daemon-driver-storage-core = 3.9.0-14.el7_5.4 for package: libvirt-daemon-driver-qemu-3.9.0-14.el7_5.4.x86_64
# --> Processing Dependency: lzop for package: libvirt-daemon-driver-qemu-3.9.0-14.el7_5.4.x86_64
# --> Processing Dependency: /usr/bin/qemu-img for package: libvirt-daemon-driver-qemu-3.9.0-14.el7_5.4.x86_64
# ---> Package libvirt-daemon-driver-secret.x86_64 0:3.9.0-14.el7_5.4 will be installed
# ---> Package libvirt-daemon-driver-storage.x86_64 0:3.9.0-14.el7_5.4 will be installed
# --> Processing Dependency: libvirt-daemon-driver-storage-scsi = 3.9.0-14.el7_5.4 for package: libvirt-daemon-driver-storage-3.9.0-14.el7_5.4.x86_64
# --> Processing Dependency: libvirt-daemon-driver-storage-rbd = 3.9.0-14.el7_5.4 for package: libvirt-daemon-driver-storage-3.9.0-14.el7_5.4.x86_64
# --> Processing Dependency: libvirt-daemon-driver-storage-mpath = 3.9.0-14.el7_5.4 for package: libvirt-daemon-driver-storage-3.9.0-14.el7_5.4.x86_64
# --> Processing Dependency: libvirt-daemon-driver-storage-logical = 3.9.0-14.el7_5.4 for package: libvirt-daemon-driver-storage-3.9.0-14.el7_5.4.x86_64
# --> Processing Dependency: libvirt-daemon-driver-storage-iscsi = 3.9.0-14.el7_5.4 for package: libvirt-daemon-driver-storage-3.9.0-14.el7_5.4.x86_64
# --> Processing Dependency: libvirt-daemon-driver-storage-gluster = 3.9.0-14.el7_5.4 for package: libvirt-daemon-driver-storage-3.9.0-14.el7_5.4.x86_64
# --> Processing Dependency: libvirt-daemon-driver-storage-disk = 3.9.0-14.el7_5.4 for package: libvirt-daemon-driver-storage-3.9.0-14.el7_5.4.x86_64
# ---> Package libvirt-libs.x86_64 0:3.9.0-14.el7_5.4 will be installed
# --> Processing Dependency: nc for package: libvirt-libs-3.9.0-14.el7_5.4.x86_64
# --> Processing Dependency: cyrus-sasl-gssapi for package: libvirt-libs-3.9.0-14.el7_5.4.x86_64
# --> Processing Dependency: cyrus-sasl for package: libvirt-libs-3.9.0-14.el7_5.4.x86_64
# ---> Package pango.x86_64 0:1.40.4-1.el7 will be installed
# --> Processing Dependency: libthai(x86-64) >= 0.1.9 for package: pango-1.40.4-1.el7.x86_64
# --> Processing Dependency: libXft(x86-64) >= 2.0.0 for package: pango-1.40.4-1.el7.x86_64
# --> Processing Dependency: harfbuzz(x86-64) >= 1.0.3 for package: pango-1.40.4-1.el7.x86_64
# --> Processing Dependency: libthai.so.0(LIBTHAI_0.1)(64bit) for package: pango-1.40.4-1.el7.x86_64
# --> Processing Dependency: libthai.so.0()(64bit) for package: pango-1.40.4-1.el7.x86_64
# --> Processing Dependency: libharfbuzz.so.0()(64bit) for package: pango-1.40.4-1.el7.x86_64
# --> Processing Dependency: libXft.so.2()(64bit) for package: pango-1.40.4-1.el7.x86_64
# ---> Package pixman.x86_64 0:0.34.0-1.el7 will be installed
# ---> Package pulseaudio-libs.x86_64 0:10.0-5.el7 will be installed
# --> Processing Dependency: libsndfile.so.1(libsndfile.so.1.0)(64bit) for package: pulseaudio-libs-10.0-5.el7.x86_64
# --> Processing Dependency: libsndfile.so.1()(64bit) for package: pulseaudio-libs-10.0-5.el7.x86_64
# --> Processing Dependency: libasyncns.so.0()(64bit) for package: pulseaudio-libs-10.0-5.el7.x86_64
# ---> Package qemu-common.x86_64 2:2.0.0-1.el7.6 will be installed
# --> Processing Dependency: qemu-kvm-common for package: 2:qemu-common-2.0.0-1.el7.6.x86_64
# ---> Package seavgabios-bin.noarch 0:1.11.0-2.el7 will be installed
# ---> Package sgabios-bin.noarch 1:0.20110622svn-4.el7 will be installed
# ---> Package spice-server.x86_64 0:0.14.0-2.el7_5.3 will be installed
# --> Processing Dependency: libopus.so.0()(64bit) for package: spice-server-0.14.0-2.el7_5.3.x86_64
# --> Processing Dependency: libcelt051.so.0()(64bit) for package: spice-server-0.14.0-2.el7_5.3.x86_64
# ---> Package usbredir.x86_64 0:0.7.1-3.el7 will be installed
# ---> Package vte3.x86_64 0:0.36.5-1.el7 will be installed
# --> Processing Dependency: vte-profile for package: vte3-0.36.5-1.el7.x86_64
# --> Running transaction check
# ---> Package adwaita-icon-theme.noarch 0:3.26.0-1.el7 will be installed
# --> Processing Dependency: adwaita-cursor-theme = 3.26.0-1.el7 for package: adwaita-icon-theme-3.26.0-1.el7.noarch
# ---> Package at-spi2-atk.x86_64 0:2.22.0-2.el7 will be installed
# --> Processing Dependency: at-spi2-core(x86-64) >= 2.17.90 for package: at-spi2-atk-2.22.0-2.el7.x86_64
# --> Processing Dependency: libatspi.so.0()(64bit) for package: at-spi2-atk-2.22.0-2.el7.x86_64
# ---> Package brltty.x86_64 0:4.5-16.el7 will be installed
# --> Processing Dependency: libicuuc.so.50()(64bit) for package: brltty-4.5-16.el7.x86_64
# --> Processing Dependency: libicui18n.so.50()(64bit) for package: brltty-4.5-16.el7.x86_64
# --> Processing Dependency: libicudata.so.50()(64bit) for package: brltty-4.5-16.el7.x86_64
# ---> Package celt051.x86_64 0:0.5.1.3-8.el7 will be installed
# --> Processing Dependency: libogg.so.0()(64bit) for package: celt051-0.5.1.3-8.el7.x86_64
# ---> Package colord-libs.x86_64 0:1.3.4-1.el7 will be installed
# --> Processing Dependency: libgusb.so.2(LIBGUSB_0.1.1)(64bit) for package: colord-libs-1.3.4-1.el7.x86_64
# --> Processing Dependency: libgusb.so.2(LIBGUSB_0.1.0)(64bit) for package: colord-libs-1.3.4-1.el7.x86_64
# --> Processing Dependency: liblcms2.so.2()(64bit) for package: colord-libs-1.3.4-1.el7.x86_64
# --> Processing Dependency: libgusb.so.2()(64bit) for package: colord-libs-1.3.4-1.el7.x86_64
# ---> Package cups-libs.x86_64 1:1.6.3-35.el7 will be installed
# ---> Package cyrus-sasl.x86_64 0:2.1.26-23.el7 will be installed
# ---> Package cyrus-sasl-gssapi.x86_64 0:2.1.26-23.el7 will be installed
# ---> Package dconf.x86_64 0:0.26.0-2.el7 will be installed
# ---> Package dnsmasq.x86_64 0:2.76-5.el7 will be installed
# ---> Package fuse-libs.x86_64 0:2.9.2-10.el7 will be installed
# ---> Package gnutls-utils.x86_64 0:3.3.26-9.el7 will be installed
# --> Processing Dependency: gnutls-dane(x86-64) = 3.3.26-9.el7 for package: gnutls-utils-3.3.26-9.el7.x86_64
# --> Processing Dependency: libgnutls-dane.so.0(DANE_0_0)(64bit) for package: gnutls-utils-3.3.26-9.el7.x86_64
# --> Processing Dependency: libunbound.so.2()(64bit) for package: gnutls-utils-3.3.26-9.el7.x86_64
# --> Processing Dependency: libopts.so.25()(64bit) for package: gnutls-utils-3.3.26-9.el7.x86_64
# --> Processing Dependency: libgnutls-dane.so.0()(64bit) for package: gnutls-utils-3.3.26-9.el7.x86_64
# ---> Package gtk-update-icon-cache.x86_64 0:3.22.26-4.el7_5 will be installed
# ---> Package harfbuzz.x86_64 0:1.3.2-1.el7 will be installed
# --> Processing Dependency: libgraphite2.so.3()(64bit) for package: harfbuzz-1.3.2-1.el7.x86_64
# ---> Package hicolor-icon-theme.noarch 0:0.12-7.el7 will be installed
# ---> Package jasper-libs.x86_64 0:1.900.1-31.el7 will be installed
# ---> Package json-glib.x86_64 0:1.2.6-1.el7 will be installed
# ---> Package libXcomposite.x86_64 0:0.4.4-4.1.el7 will be installed
# ---> Package libXft.x86_64 0:2.3.2-2.el7 will be installed
# ---> Package libXi.x86_64 0:1.7.9-1.el7 will be installed
# ---> Package libXrandr.x86_64 0:1.5.1-2.el7 will be installed
# ---> Package libXtst.x86_64 0:1.2.3-1.el7 will be installed
# ---> Package libasyncns.x86_64 0:0.8-7.el7 will be installed
# ---> Package libcgroup.x86_64 0:0.41-15.el7 will be installed
# ---> Package libepoxy.x86_64 0:1.3.1-2.el7_5 will be installed
# ---> Package libpcap.x86_64 14:1.5.3-11.el7 will be installed
# ---> Package libsndfile.x86_64 0:1.0.25-10.el7 will be installed
# --> Processing Dependency: libvorbisenc.so.2()(64bit) for package: libsndfile-1.0.25-10.el7.x86_64
# --> Processing Dependency: libvorbis.so.0()(64bit) for package: libsndfile-1.0.25-10.el7.x86_64
# --> Processing Dependency: libgsm.so.1()(64bit) for package: libsndfile-1.0.25-10.el7.x86_64
# --> Processing Dependency: libFLAC.so.8()(64bit) for package: libsndfile-1.0.25-10.el7.x86_64
# ---> Package libthai.x86_64 0:0.1.14-9.el7 will be installed
# ---> Package libtiff.x86_64 0:4.0.3-27.el7_3 will be installed
# --> Processing Dependency: libjbig.so.2.0()(64bit) for package: libtiff-4.0.3-27.el7_3.x86_64
# ---> Package libvirt-daemon-driver-storage-core.x86_64 0:3.9.0-14.el7_5.4 will be installed
# --> Processing Dependency: nfs-utils for package: libvirt-daemon-driver-storage-core-3.9.0-14.el7_5.4.x86_64
# ---> Package libvirt-daemon-driver-storage-disk.x86_64 0:3.9.0-14.el7_5.4 will be installed
# ---> Package libvirt-daemon-driver-storage-gluster.x86_64 0:3.9.0-14.el7_5.4 will be installed
# --> Processing Dependency: libgfapi.so.0(GFAPI_3.4.0)(64bit) for package: libvirt-daemon-driver-storage-gluster-3.9.0-14.el7_5.4.x86_64
# --> Processing Dependency: /usr/sbin/gluster for package: libvirt-daemon-driver-storage-gluster-3.9.0-14.el7_5.4.x86_64
# --> Processing Dependency: libglusterfs.so.0()(64bit) for package: libvirt-daemon-driver-storage-gluster-3.9.0-14.el7_5.4.x86_64
# --> Processing Dependency: libgfxdr.so.0()(64bit) for package: libvirt-daemon-driver-storage-gluster-3.9.0-14.el7_5.4.x86_64
# --> Processing Dependency: libgfrpc.so.0()(64bit) for package: libvirt-daemon-driver-storage-gluster-3.9.0-14.el7_5.4.x86_64
# --> Processing Dependency: libgfapi.so.0()(64bit) for package: libvirt-daemon-driver-storage-gluster-3.9.0-14.el7_5.4.x86_64
# ---> Package libvirt-daemon-driver-storage-iscsi.x86_64 0:3.9.0-14.el7_5.4 will be installed
# --> Processing Dependency: iscsi-initiator-utils for package: libvirt-daemon-driver-storage-iscsi-3.9.0-14.el7_5.4.x86_64
# ---> Package libvirt-daemon-driver-storage-logical.x86_64 0:3.9.0-14.el7_5.4 will be installed
# ---> Package libvirt-daemon-driver-storage-mpath.x86_64 0:3.9.0-14.el7_5.4 will be installed
# ---> Package libvirt-daemon-driver-storage-rbd.x86_64 0:3.9.0-14.el7_5.4 will be installed
# --> Processing Dependency: librbd.so.1()(64bit) for package: libvirt-daemon-driver-storage-rbd-3.9.0-14.el7_5.4.x86_64
# --> Processing Dependency: librados.so.2()(64bit) for package: libvirt-daemon-driver-storage-rbd-3.9.0-14.el7_5.4.x86_64
# ---> Package libvirt-daemon-driver-storage-scsi.x86_64 0:3.9.0-14.el7_5.4 will be installed
# ---> Package libwayland-client.x86_64 0:1.14.0-2.el7 will be installed
# ---> Package libwayland-cursor.x86_64 0:1.14.0-2.el7 will be installed
# ---> Package libxkbcommon.x86_64 0:0.7.1-1.el7 will be installed
# --> Processing Dependency: xkeyboard-config for package: libxkbcommon-0.7.1-1.el7.x86_64
# ---> Package lzop.x86_64 0:1.03-10.el7 will be installed
# ---> Package mesa-libEGL.x86_64 0:17.2.3-8.20171019.el7 will be installed
# --> Processing Dependency: mesa-libgbm = 17.2.3-8.20171019.el7 for package: mesa-libEGL-17.2.3-8.20171019.el7.x86_64
# --> Processing Dependency: libwayland-server.so.0()(64bit) for package: mesa-libEGL-17.2.3-8.20171019.el7.x86_64
# --> Processing Dependency: libgbm.so.1()(64bit) for package: mesa-libEGL-17.2.3-8.20171019.el7.x86_64
# ---> Package mesa-libwayland-egl.x86_64 0:17.2.3-8.20171019.el7 will be installed
# ---> Package netcf-libs.x86_64 0:0.2.8-4.el7 will be installed
# --> Processing Dependency: libaugeas.so.0(AUGEAS_0.8.0)(64bit) for package: netcf-libs-0.2.8-4.el7.x86_64
# --> Processing Dependency: libaugeas.so.0(AUGEAS_0.1.0)(64bit) for package: netcf-libs-0.2.8-4.el7.x86_64
# --> Processing Dependency: bridge-utils for package: netcf-libs-0.2.8-4.el7.x86_64
# --> Processing Dependency: libaugeas.so.0()(64bit) for package: netcf-libs-0.2.8-4.el7.x86_64
# ---> Package nmap-ncat.x86_64 2:6.40-13.el7 will be installed
# ---> Package numad.x86_64 0:0.5-18.20150602git.el7 will be installed
# ---> Package opus.x86_64 0:1.0.2-6.el7 will be installed
# ---> Package qemu-img.x86_64 10:1.5.3-156.el7_5.1 will be installed
# --> Processing Dependency: libtcmalloc.so.4()(64bit) for package: 10:qemu-img-1.5.3-156.el7_5.1.x86_64
# ---> Package qemu-kvm-common.x86_64 10:1.5.3-156.el7_5.1 will be installed
# ---> Package radvd.x86_64 0:1.9.2-9.el7_5.4 will be installed
# ---> Package rdma-core.x86_64 0:15-7.el7_5 will be installed
# --> Processing Dependency: pciutils for package: rdma-core-15-7.el7_5.x86_64
# ---> Package rest.x86_64 0:0.8.0-2.el7 will be installed
# --> Processing Dependency: libsoup-gnome-2.4.so.1()(64bit) for package: rest-0.8.0-2.el7.x86_64
# --> Processing Dependency: libsoup-2.4.so.1()(64bit) for package: rest-0.8.0-2.el7.x86_64
# ---> Package vte-profile.x86_64 0:0.46.2-1.el7 will be installed
# ---> Package yajl.x86_64 0:2.0.4-4.el7 will be installed
# --> Running transaction check
# ---> Package adwaita-cursor-theme.noarch 0:3.26.0-1.el7 will be installed
# ---> Package at-spi2-core.x86_64 0:2.22.0-1.el7 will be installed
# ---> Package augeas-libs.x86_64 0:1.4.0-5.el7_5.1 will be installed
# ---> Package autogen-libopts.x86_64 0:5.18-5.el7 will be installed
# ---> Package bridge-utils.x86_64 0:1.5-9.el7 will be installed
# ---> Package flac-libs.x86_64 0:1.3.0-5.el7_1 will be installed
# ---> Package glusterfs-api.x86_64 0:3.8.4-53.el7.centos will be installed
# --> Processing Dependency: glusterfs-client-xlators(x86-64) = 3.8.4-53.el7.centos for package: glusterfs-api-3.8.4-53.el7.centos.x86_64
# --> Processing Dependency: glusterfs(x86-64) = 3.8.4-53.el7.centos for package: glusterfs-api-3.8.4-53.el7.centos.x86_64
# ---> Package glusterfs-cli.x86_64 0:3.8.4-53.el7.centos will be installed
# ---> Package glusterfs-libs.x86_64 0:3.8.4-53.el7.centos will be installed
# ---> Package gnutls-dane.x86_64 0:3.3.26-9.el7 will be installed
# ---> Package gperftools-libs.x86_64 0:2.6.1-1.el7 will be installed
# ---> Package graphite2.x86_64 0:1.3.10-1.el7_3 will be installed
# ---> Package gsm.x86_64 0:1.0.13-11.el7 will be installed
# ---> Package iscsi-initiator-utils.x86_64 0:6.2.0.874-7.el7 will be installed
# --> Processing Dependency: iscsi-initiator-utils-iscsiuio >= 6.2.0.874-7.el7 for package: iscsi-initiator-utils-6.2.0.874-7.el7.x86_64
# ---> Package jbigkit-libs.x86_64 0:2.0-11.el7 will be installed
# ---> Package lcms2.x86_64 0:2.6-3.el7 will be installed
# ---> Package libgusb.x86_64 0:0.2.9-1.el7 will be installed
# ---> Package libicu.x86_64 0:50.1.2-15.el7 will be installed
# ---> Package libogg.x86_64 2:1.3.0-7.el7 will be installed
# ---> Package librados2.x86_64 1:0.94.5-2.el7 will be installed
# ---> Package librbd1.x86_64 1:0.94.5-2.el7 will be installed
# ---> Package libsoup.x86_64 0:2.56.0-6.el7 will be installed
# --> Processing Dependency: glib-networking(x86-64) >= 2.38.0 for package: libsoup-2.56.0-6.el7.x86_64
# ---> Package libvorbis.x86_64 1:1.3.3-8.el7.1 will be installed
# ---> Package libwayland-server.x86_64 0:1.14.0-2.el7 will be installed
# ---> Package mesa-libgbm.x86_64 0:17.2.3-8.20171019.el7 will be installed
# ---> Package nfs-utils.x86_64 1:1.3.0-0.54.el7 will be installed
# --> Processing Dependency: libtirpc >= 0.2.4-0.7 for package: 1:nfs-utils-1.3.0-0.54.el7.x86_64
# --> Processing Dependency: gssproxy >= 0.7.0-3 for package: 1:nfs-utils-1.3.0-0.54.el7.x86_64
# --> Processing Dependency: rpcbind for package: 1:nfs-utils-1.3.0-0.54.el7.x86_64
# --> Processing Dependency: quota for package: 1:nfs-utils-1.3.0-0.54.el7.x86_64
# --> Processing Dependency: libnfsidmap for package: 1:nfs-utils-1.3.0-0.54.el7.x86_64
# --> Processing Dependency: libevent for package: 1:nfs-utils-1.3.0-0.54.el7.x86_64
# --> Processing Dependency: keyutils for package: 1:nfs-utils-1.3.0-0.54.el7.x86_64
# --> Processing Dependency: libtirpc.so.1()(64bit) for package: 1:nfs-utils-1.3.0-0.54.el7.x86_64
# --> Processing Dependency: libnfsidmap.so.0()(64bit) for package: 1:nfs-utils-1.3.0-0.54.el7.x86_64
# --> Processing Dependency: libevent-2.0.so.5()(64bit) for package: 1:nfs-utils-1.3.0-0.54.el7.x86_64
# ---> Package pciutils.x86_64 0:3.5.1-3.el7 will be installed
# ---> Package unbound-libs.x86_64 0:1.6.6-1.el7 will be installed
# ---> Package xkeyboard-config.noarch 0:2.20-1.el7 will be installed
# --> Running transaction check
# ---> Package glib-networking.x86_64 0:2.50.0-1.el7 will be installed
# --> Processing Dependency: gsettings-desktop-schemas for package: glib-networking-2.50.0-1.el7.x86_64
# ---> Package glusterfs.x86_64 0:3.8.4-53.el7.centos will be installed
# ---> Package glusterfs-client-xlators.x86_64 0:3.8.4-53.el7.centos will be installed
# ---> Package gssproxy.x86_64 0:0.7.0-17.el7 will be installed
# --> Processing Dependency: libini_config >= 1.3.1-28 for package: gssproxy-0.7.0-17.el7.x86_64
# --> Processing Dependency: libverto-module-base for package: gssproxy-0.7.0-17.el7.x86_64
# --> Processing Dependency: libref_array.so.1(REF_ARRAY_0.1.1)(64bit) for package: gssproxy-0.7.0-17.el7.x86_64
# --> Processing Dependency: libini_config.so.3(INI_CONFIG_1.2.0)(64bit) for package: gssproxy-0.7.0-17.el7.x86_64
# --> Processing Dependency: libini_config.so.3(INI_CONFIG_1.1.0)(64bit) for package: gssproxy-0.7.0-17.el7.x86_64
# --> Processing Dependency: libref_array.so.1()(64bit) for package: gssproxy-0.7.0-17.el7.x86_64
# --> Processing Dependency: libini_config.so.3()(64bit) for package: gssproxy-0.7.0-17.el7.x86_64
# --> Processing Dependency: libcollection.so.2()(64bit) for package: gssproxy-0.7.0-17.el7.x86_64
# --> Processing Dependency: libbasicobjects.so.0()(64bit) for package: gssproxy-0.7.0-17.el7.x86_64
# ---> Package iscsi-initiator-utils-iscsiuio.x86_64 0:6.2.0.874-7.el7 will be installed
# ---> Package keyutils.x86_64 0:1.5.8-3.el7 will be installed
# ---> Package libevent.x86_64 0:2.0.21-4.el7 will be installed
# ---> Package libnfsidmap.x86_64 0:0.25-19.el7 will be installed
# ---> Package libtirpc.x86_64 0:0.2.4-0.10.el7 will be installed
# ---> Package quota.x86_64 1:4.01-17.el7 will be installed
# --> Processing Dependency: quota-nls = 1:4.01-17.el7 for package: 1:quota-4.01-17.el7.x86_64
# --> Processing Dependency: tcp_wrappers for package: 1:quota-4.01-17.el7.x86_64
# ---> Package rpcbind.x86_64 0:0.2.0-44.el7 will be installed
# --> Running transaction check
# ---> Package gsettings-desktop-schemas.x86_64 0:3.24.1-1.el7 will be installed
# ---> Package libbasicobjects.x86_64 0:0.1.1-29.el7 will be installed
# ---> Package libcollection.x86_64 0:0.7.0-29.el7 will be installed
# ---> Package libini_config.x86_64 0:1.3.1-29.el7 will be installed
# --> Processing Dependency: libpath_utils.so.1(PATH_UTILS_0.2.1)(64bit) for package: libini_config-1.3.1-29.el7.x86_64
# --> Processing Dependency: libpath_utils.so.1()(64bit) for package: libini_config-1.3.1-29.el7.x86_64
# ---> Package libref_array.x86_64 0:0.1.5-29.el7 will be installed
# ---> Package libverto-libevent.x86_64 0:0.2.5-4.el7 will be installed
# ---> Package quota-nls.noarch 1:4.01-17.el7 will be installed
# ---> Package tcp_wrappers.x86_64 0:7.6-77.el7 will be installed
# --> Running transaction check
# ---> Package libpath_utils.x86_64 0:0.2.1-29.el7 will be installed
# --> Finished Dependency Resolution
#
# Dependencies Resolved
#
# ================================================================================
#  Package                             Arch   Version               Repository
#                                                                            Size
# ================================================================================
# Installing:
#  libvirt                             x86_64 3.9.0-14.el7_5.4      updates 173 k
#  qemu-system-x86                     x86_64 2:2.0.0-1.el7.6       epel    3.4 M
# Installing for dependencies:
#  adwaita-cursor-theme                noarch 3.26.0-1.el7          base    641 k
#  adwaita-icon-theme                  noarch 3.26.0-1.el7          base     12 M
#  at-spi2-atk                         x86_64 2.22.0-2.el7          base     80 k
#  at-spi2-core                        x86_64 2.22.0-1.el7          base    157 k
#  atk                                 x86_64 2.22.0-3.el7          base    258 k
#  augeas-libs                         x86_64 1.4.0-5.el7_5.1       updates 355 k
#  autogen-libopts                     x86_64 5.18-5.el7            base     66 k
#  bluez-libs                          x86_64 5.44-4.el7_4          base     80 k
#  bridge-utils                        x86_64 1.5-9.el7             base     32 k
#  brlapi                              x86_64 0.6.0-16.el7          base    114 k
#  brltty                              x86_64 4.5-16.el7            base    933 k
#  cairo                               x86_64 1.14.8-2.el7          base    713 k
#  cairo-gobject                       x86_64 1.14.8-2.el7          base     25 k
#  celt051                             x86_64 0.5.1.3-8.el7         base     53 k
#  colord-libs                         x86_64 1.3.4-1.el7           base    185 k
#  cups-libs                           x86_64 1:1.6.3-35.el7        base    357 k
#  cyrus-sasl                          x86_64 2.1.26-23.el7         base     88 k
#  cyrus-sasl-gssapi                   x86_64 2.1.26-23.el7         base     41 k
#  dconf                               x86_64 0.26.0-2.el7          base    107 k
#  dnsmasq                             x86_64 2.76-5.el7            base    277 k
#  flac-libs                           x86_64 1.3.0-5.el7_1         base    169 k
#  fuse-libs                           x86_64 2.9.2-10.el7          base     93 k
#  gdk-pixbuf2                         x86_64 2.36.5-1.el7          base    567 k
#  glib-networking                     x86_64 2.50.0-1.el7          base    131 k
#  glusterfs                           x86_64 3.8.4-53.el7.centos   base    529 k
#  glusterfs-api                       x86_64 3.8.4-53.el7.centos   base     75 k
#  glusterfs-cli                       x86_64 3.8.4-53.el7.centos   base    176 k
#  glusterfs-client-xlators            x86_64 3.8.4-53.el7.centos   base    789 k
#  glusterfs-libs                      x86_64 3.8.4-53.el7.centos   base    370 k
#  gnutls-dane                         x86_64 3.3.26-9.el7          base     34 k
#  gnutls-utils                        x86_64 3.3.26-9.el7          base    237 k
#  gperftools-libs                     x86_64 2.6.1-1.el7           base    272 k
#  graphite2                           x86_64 1.3.10-1.el7_3        base    115 k
#  gsettings-desktop-schemas           x86_64 3.24.1-1.el7          base    586 k
#  gsm                                 x86_64 1.0.13-11.el7         base     30 k
#  gssproxy                            x86_64 0.7.0-17.el7          base    108 k
#  gtk-update-icon-cache               x86_64 3.22.26-4.el7_5       updates  27 k
#  gtk3                                x86_64 3.22.26-4.el7_5       updates 4.4 M
#  harfbuzz                            x86_64 1.3.2-1.el7           base    177 k
#  hicolor-icon-theme                  noarch 0.12-7.el7            base     42 k
#  ipxe-roms-qemu                      noarch 20170123-1.git4e85b27.el7_4.1
#                                                                   base    759 k
#  iscsi-initiator-utils               x86_64 6.2.0.874-7.el7       base    422 k
#  iscsi-initiator-utils-iscsiuio      x86_64 6.2.0.874-7.el7       base     90 k
#  jasper-libs                         x86_64 1.900.1-31.el7        base    150 k
#  jbigkit-libs                        x86_64 2.0-11.el7            base     46 k
#  json-glib                           x86_64 1.2.6-1.el7           base    133 k
#  keyutils                            x86_64 1.5.8-3.el7           base     54 k
#  lcms2                               x86_64 2.6-3.el7             base    150 k
#  libXcomposite                       x86_64 0.4.4-4.1.el7         base     22 k
#  libXft                              x86_64 2.3.2-2.el7           base     58 k
#  libXi                               x86_64 1.7.9-1.el7           base     40 k
#  libXrandr                           x86_64 1.5.1-2.el7           base     27 k
#  libXtst                             x86_64 1.2.3-1.el7           base     20 k
#  libasyncns                          x86_64 0.8-7.el7             base     26 k
#  libbasicobjects                     x86_64 0.1.1-29.el7          base     25 k
#  libcgroup                           x86_64 0.41-15.el7           base     65 k
#  libcollection                       x86_64 0.7.0-29.el7          base     41 k
#  libepoxy                            x86_64 1.3.1-2.el7_5         updates 196 k
#  libevent                            x86_64 2.0.21-4.el7          base    214 k
#  libgusb                             x86_64 0.2.9-1.el7           base     40 k
#  libibverbs                          x86_64 15-7.el7_5            updates 224 k
#  libicu                              x86_64 50.1.2-15.el7         base    6.9 M
#  libini_config                       x86_64 1.3.1-29.el7          base     63 k
#  libiscsi                            x86_64 1.9.0-7.el7           base     60 k
#  libnfsidmap                         x86_64 0.25-19.el7           base     50 k
#  libogg                              x86_64 2:1.3.0-7.el7         base     24 k
#  libpath_utils                       x86_64 0.2.1-29.el7          base     28 k
#  libpcap                             x86_64 14:1.5.3-11.el7       base    138 k
#  librados2                           x86_64 1:0.94.5-2.el7        base    1.7 M
#  librbd1                             x86_64 1:0.94.5-2.el7        base    1.8 M
#  librdmacm                           x86_64 15-7.el7_5            updates  61 k
#  libref_array                        x86_64 0.1.5-29.el7          base     26 k
#  libsndfile                          x86_64 1.0.25-10.el7         base    149 k
#  libsoup                             x86_64 2.56.0-6.el7          base    398 k
#  libthai                             x86_64 0.1.14-9.el7          base    187 k
#  libtiff                             x86_64 4.0.3-27.el7_3        base    170 k
#  libtirpc                            x86_64 0.2.4-0.10.el7        base     88 k
#  libusbx                             x86_64 1.0.21-1.el7          base     61 k
#  libverto-libevent                   x86_64 0.2.5-4.el7           base    8.9 k
#  libvirt-client                      x86_64 3.9.0-14.el7_5.4      updates 459 k
#  libvirt-daemon                      x86_64 3.9.0-14.el7_5.4      updates 851 k
#  libvirt-daemon-config-network       x86_64 3.9.0-14.el7_5.4      updates 175 k
#  libvirt-daemon-config-nwfilter      x86_64 3.9.0-14.el7_5.4      updates 180 k
#  libvirt-daemon-driver-interface     x86_64 3.9.0-14.el7_5.4      updates 220 k
#  libvirt-daemon-driver-lxc           x86_64 3.9.0-14.el7_5.4      updates 901 k
#  libvirt-daemon-driver-network       x86_64 3.9.0-14.el7_5.4      updates 388 k
#  libvirt-daemon-driver-nodedev       x86_64 3.9.0-14.el7_5.4      updates 221 k
#  libvirt-daemon-driver-nwfilter      x86_64 3.9.0-14.el7_5.4      updates 243 k
#  libvirt-daemon-driver-qemu          x86_64 3.9.0-14.el7_5.4      updates 714 k
#  libvirt-daemon-driver-secret        x86_64 3.9.0-14.el7_5.4      updates 210 k
#  libvirt-daemon-driver-storage       x86_64 3.9.0-14.el7_5.4      updates 173 k
#  libvirt-daemon-driver-storage-core  x86_64 3.9.0-14.el7_5.4      updates 404 k
#  libvirt-daemon-driver-storage-disk  x86_64 3.9.0-14.el7_5.4      updates 181 k
#  libvirt-daemon-driver-storage-gluster
#                                      x86_64 3.9.0-14.el7_5.4      updates 182 k
#  libvirt-daemon-driver-storage-iscsi x86_64 3.9.0-14.el7_5.4      updates 179 k
#  libvirt-daemon-driver-storage-logical
#                                      x86_64 3.9.0-14.el7_5.4      updates 183 k
#  libvirt-daemon-driver-storage-mpath x86_64 3.9.0-14.el7_5.4      updates 177 k
#  libvirt-daemon-driver-storage-rbd   x86_64 3.9.0-14.el7_5.4      updates 184 k
#  libvirt-daemon-driver-storage-scsi  x86_64 3.9.0-14.el7_5.4      updates 179 k
#  libvirt-libs                        x86_64 3.9.0-14.el7_5.4      updates 4.1 M
#  libvorbis                           x86_64 1:1.3.3-8.el7.1       updates 204 k
#  libwayland-client                   x86_64 1.14.0-2.el7          base     32 k
#  libwayland-cursor                   x86_64 1.14.0-2.el7          base     20 k
#  libwayland-server                   x86_64 1.14.0-2.el7          base     38 k
#  libxkbcommon                        x86_64 0.7.1-1.el7           base    108 k
#  lzop                                x86_64 1.03-10.el7           base     54 k
#  mesa-libEGL                         x86_64 17.2.3-8.20171019.el7 base     96 k
#  mesa-libgbm                         x86_64 17.2.3-8.20171019.el7 base     38 k
#  mesa-libwayland-egl                 x86_64 17.2.3-8.20171019.el7 base     17 k
#  netcf-libs                          x86_64 0.2.8-4.el7           base     70 k
#  nfs-utils                           x86_64 1:1.3.0-0.54.el7      base    407 k
#  nmap-ncat                           x86_64 2:6.40-13.el7         base    205 k
#  numad                               x86_64 0.5-18.20150602git.el7
#                                                                   base     35 k
#  opus                                x86_64 1.0.2-6.el7           base    630 k
#  pango                               x86_64 1.40.4-1.el7          base    275 k
#  pciutils                            x86_64 3.5.1-3.el7           base     93 k
#  pixman                              x86_64 0.34.0-1.el7          base    248 k
#  pulseaudio-libs                     x86_64 10.0-5.el7            base    651 k
#  qemu-common                         x86_64 2:2.0.0-1.el7.6       epel    236 k
#  qemu-img                            x86_64 10:1.5.3-156.el7_5.1  updates 691 k
#  qemu-kvm-common                     x86_64 10:1.5.3-156.el7_5.1  updates 428 k
#  quota                               x86_64 1:4.01-17.el7         base    179 k
#  quota-nls                           noarch 1:4.01-17.el7         base     90 k
#  radvd                               x86_64 1.9.2-9.el7_5.4       updates  85 k
#  rdma-core                           x86_64 15-7.el7_5            updates  48 k
#  rest                                x86_64 0.8.0-2.el7           base     63 k
#  rpcbind                             x86_64 0.2.0-44.el7          base     59 k
#  seavgabios-bin                      noarch 1.11.0-2.el7          base     38 k
#  sgabios-bin                         noarch 1:0.20110622svn-4.el7 base    7.1 k
#  spice-server                        x86_64 0.14.0-2.el7_5.3      updates 402 k
#  tcp_wrappers                        x86_64 7.6-77.el7            base     78 k
#  unbound-libs                        x86_64 1.6.6-1.el7           base    405 k
#  usbredir                            x86_64 0.7.1-3.el7           base     47 k
#  vte-profile                         x86_64 0.46.2-1.el7          base    6.9 k
#  vte3                                x86_64 0.36.5-1.el7          base    337 k
#  xkeyboard-config                    noarch 2.20-1.el7            base    799 k
#  yajl                                x86_64 2.0.4-4.el7           base     39 k
#
# Transaction Summary
# ================================================================================
# Install  2 Packages (+137 Dependent packages)
#
# Total download size: 61 M
# Installed size: 190 M
# Downloading packages:
# (1/139): at-spi2-core-2.22.0-1.el7.x86_64.rpm              | 157 kB   00:00
# (2/139): at-spi2-atk-2.22.0-2.el7.x86_64.rpm               |  80 kB   00:00
# (3/139): autogen-libopts-5.18-5.el7.x86_64.rpm             |  66 kB   00:00
# (4/139): bluez-libs-5.44-4.el7_4.x86_64.rpm                |  80 kB   00:00
# (5/139): bridge-utils-1.5-9.el7.x86_64.rpm                 |  32 kB   00:00
# (6/139): adwaita-icon-theme-3.26.0-1.el7.noarch.rpm        |  12 MB   00:03
# (7/139): adwaita-cursor-theme-3.26.0-1.el7.noarch.rpm      | 641 kB   00:03
# (8/139): atk-2.22.0-3.el7.x86_64.rpm                       | 258 kB   00:03
# (9/139): brlapi-0.6.0-16.el7.x86_64.rpm                    | 114 kB   00:00
# (10/139): augeas-libs-1.4.0-5.el7_5.1.x86_64.rpm           | 355 kB   00:03
# (11/139): brltty-4.5-16.el7.x86_64.rpm                     | 933 kB   00:00
# (12/139): cairo-gobject-1.14.8-2.el7.x86_64.rpm            |  25 kB   00:00
# (13/139): celt051-0.5.1.3-8.el7.x86_64.rpm                 |  53 kB   00:00
# (14/139): cairo-1.14.8-2.el7.x86_64.rpm                    | 713 kB   00:01
# (15/139): colord-libs-1.3.4-1.el7.x86_64.rpm               | 185 kB   00:00
# (16/139): cups-libs-1.6.3-35.el7.x86_64.rpm                | 357 kB   00:00
# (17/139): cyrus-sasl-2.1.26-23.el7.x86_64.rpm              |  88 kB   00:00
# (18/139): cyrus-sasl-gssapi-2.1.26-23.el7.x86_64.rpm       |  41 kB   00:00
# (19/139): dconf-0.26.0-2.el7.x86_64.rpm                    | 107 kB   00:00
# (20/139): dnsmasq-2.76-5.el7.x86_64.rpm                    | 277 kB   00:00
# (21/139): flac-libs-1.3.0-5.el7_1.x86_64.rpm               | 169 kB   00:00
# (22/139): fuse-libs-2.9.2-10.el7.x86_64.rpm                |  93 kB   00:00
# (23/139): glib-networking-2.50.0-1.el7.x86_64.rpm          | 131 kB   00:00
# (24/139): gdk-pixbuf2-2.36.5-1.el7.x86_64.rpm              | 567 kB   00:00
# (25/139): glusterfs-api-3.8.4-53.el7.centos.x86_64.rpm     |  75 kB   00:00
# (26/139): glusterfs-3.8.4-53.el7.centos.x86_64.rpm         | 529 kB   00:00
# (27/139): glusterfs-cli-3.8.4-53.el7.centos.x86_64.rpm     | 176 kB   00:00
# (28/139): glusterfs-client-xlators-3.8.4-53.el7.centos.x86 | 789 kB   00:00
# (29/139): glusterfs-libs-3.8.4-53.el7.centos.x86_64.rpm    | 370 kB   00:00
# (30/139): gnutls-dane-3.3.26-9.el7.x86_64.rpm              |  34 kB   00:00
# (31/139): gnutls-utils-3.3.26-9.el7.x86_64.rpm             | 237 kB   00:00
# (32/139): gperftools-libs-2.6.1-1.el7.x86_64.rpm           | 272 kB   00:00
# (33/139): graphite2-1.3.10-1.el7_3.x86_64.rpm              | 115 kB   00:00
# (34/139): gsm-1.0.13-11.el7.x86_64.rpm                     |  30 kB   00:00
# (35/139): gssproxy-0.7.0-17.el7.x86_64.rpm                 | 108 kB   00:00
# (36/139): gsettings-desktop-schemas-3.24.1-1.el7.x86_64.rp | 586 kB   00:01
# (37/139): harfbuzz-1.3.2-1.el7.x86_64.rpm                  | 177 kB   00:00
# (38/139): hicolor-icon-theme-0.12-7.el7.noarch.rpm         |  42 kB   00:00
# (39/139): gtk-update-icon-cache-3.22.26-4.el7_5.x86_64.rpm |  27 kB   00:00
# (40/139): ipxe-roms-qemu-20170123-1.git4e85b27.el7_4.1.noa | 759 kB   00:00
# (41/139): iscsi-initiator-utils-6.2.0.874-7.el7.x86_64.rpm | 422 kB   00:00
# (42/139): jbigkit-libs-2.0-11.el7.x86_64.rpm               |  46 kB   00:00
# (43/139): iscsi-initiator-utils-iscsiuio-6.2.0.874-7.el7.x |  90 kB   00:01
# (44/139): keyutils-1.5.8-3.el7.x86_64.rpm                  |  54 kB   00:00
# (45/139): jasper-libs-1.900.1-31.el7.x86_64.rpm            | 150 kB   00:01
# (46/139): libXcomposite-0.4.4-4.1.el7.x86_64.rpm           |  22 kB   00:00
# (47/139): json-glib-1.2.6-1.el7.x86_64.rpm                 | 133 kB   00:01
# (48/139): libXi-1.7.9-1.el7.x86_64.rpm                     |  40 kB   00:00
# (49/139): lcms2-2.6-3.el7.x86_64.rpm                       | 150 kB   00:00
# (50/139): libXft-2.3.2-2.el7.x86_64.rpm                    |  58 kB   00:00
# (51/139): libXrandr-1.5.1-2.el7.x86_64.rpm                 |  27 kB   00:00
# (52/139): libXtst-1.2.3-1.el7.x86_64.rpm                   |  20 kB   00:00
# (53/139): libasyncns-0.8-7.el7.x86_64.rpm                  |  26 kB   00:00
# (54/139): libcollection-0.7.0-29.el7.x86_64.rpm            |  41 kB   00:00
# (55/139): libbasicobjects-0.1.1-29.el7.x86_64.rpm          |  25 kB   00:00
# (56/139): libcgroup-0.41-15.el7.x86_64.rpm                 |  65 kB   00:00
# ...
#   Verifying  : ipxe-roms-qemu-20170123-1.git4e85b27.el7_4.1.noarch       81/139
#   Verifying  : 2:qemu-system-x86-2.0.0-1.el7.6.x86_64                    82/139
#   Verifying  : libvirt-daemon-driver-storage-logical-3.9.0-14.el7_5.4    83/139
#   Verifying  : libvirt-daemon-config-network-3.9.0-14.el7_5.4.x86_64     84/139
#   Verifying  : libvirt-daemon-driver-interface-3.9.0-14.el7_5.4.x86_6    85/139
#   Verifying  : glusterfs-cli-3.8.4-53.el7.centos.x86_64                  86/139
#   Verifying  : cyrus-sasl-gssapi-2.1.26-23.el7.x86_64                    87/139
#   Verifying  : libcgroup-0.41-15.el7.x86_64                              88/139
#   Verifying  : libiscsi-1.9.0-7.el7.x86_64                               89/139
#   Verifying  : libevent-2.0.21-4.el7.x86_64                              90/139
#   Verifying  : glusterfs-libs-3.8.4-53.el7.centos.x86_64                 91/139
#   Verifying  : fuse-libs-2.9.2-10.el7.x86_64                             92/139
#   Verifying  : libXrandr-1.5.1-2.el7.x86_64                              93/139
#   Verifying  : gtk-update-icon-cache-3.22.26-4.el7_5.x86_64              94/139
#   Verifying  : 14:libpcap-1.5.3-11.el7.x86_64                            95/139
#   Verifying  : 1:quota-4.01-17.el7.x86_64                                96/139
#   Verifying  : at-spi2-atk-2.22.0-2.el7.x86_64                           97/139
#   Verifying  : libvirt-daemon-driver-nwfilter-3.9.0-14.el7_5.4.x86_64    98/139
#   Verifying  : celt051-0.5.1.3-8.el7.x86_64                              99/139
#   Verifying  : glusterfs-3.8.4-53.el7.centos.x86_64                     100/139
#   Verifying  : libvirt-daemon-config-nwfilter-3.9.0-14.el7_5.4.x86_64   101/139
#   Verifying  : 2:nmap-ncat-6.40-13.el7.x86_64                           102/139
#   Verifying  : libwayland-server-1.14.0-2.el7.x86_64                    103/139
#   Verifying  : libvirt-daemon-driver-storage-scsi-3.9.0-14.el7_5.4.x8   104/139
#   Verifying  : libini_config-1.3.1-29.el7.x86_64                        105/139
#   Verifying  : atk-2.22.0-3.el7.x86_64                                  106/139
#   Verifying  : libtirpc-0.2.4-0.10.el7.x86_64                           107/139
#   Verifying  : 2:qemu-common-2.0.0-1.el7.6.x86_64                       108/139
#   Verifying  : graphite2-1.3.10-1.el7_3.x86_64                          109/139
#   Verifying  : keyutils-1.5.8-3.el7.x86_64                              110/139
#   Verifying  : cairo-1.14.8-2.el7.x86_64                                111/139
#   Verifying  : libasyncns-0.8-7.el7.x86_64                              112/139
#   Verifying  : gssproxy-0.7.0-17.el7.x86_64                             113/139
#   Verifying  : librdmacm-15-7.el7_5.x86_64                              114/139
#   Verifying  : libvirt-daemon-driver-nodedev-3.9.0-14.el7_5.4.x86_64    115/139
#   Verifying  : libthai-0.1.14-9.el7.x86_64                              116/139
#   Verifying  : libvirt-daemon-driver-storage-mpath-3.9.0-14.el7_5.4.x   117/139
#   Verifying  : libXft-2.3.2-2.el7.x86_64                                118/139
#   Verifying  : libvirt-daemon-3.9.0-14.el7_5.4.x86_64                   119/139
#   Verifying  : json-glib-1.2.6-1.el7.x86_64                             120/139
#   Verifying  : 1:quota-nls-4.01-17.el7.noarch                           121/139
#   Verifying  : netcf-libs-0.2.8-4.el7.x86_64                            122/139
#   Verifying  : libusbx-1.0.21-1.el7.x86_64                              123/139
#   Verifying  : libibverbs-15-7.el7_5.x86_64                             124/139
#   Verifying  : flac-libs-1.3.0-5.el7_1.x86_64                           125/139
#   Verifying  : opus-1.0.2-6.el7.x86_64                                  126/139
#   Verifying  : adwaita-icon-theme-3.26.0-1.el7.noarch                   127/139
#   Verifying  : gnutls-utils-3.3.26-9.el7.x86_64                         128/139
#   Verifying  : adwaita-cursor-theme-3.26.0-1.el7.noarch                 129/139
#   Verifying  : glusterfs-api-3.8.4-53.el7.centos.x86_64                 130/139
#   Verifying  : libgusb-0.2.9-1.el7.x86_64                               131/139
#   Verifying  : jbigkit-libs-2.0-11.el7.x86_64                           132/139
#   Verifying  : dnsmasq-2.76-5.el7.x86_64                                133/139
#   Verifying  : gdk-pixbuf2-2.36.5-1.el7.x86_64                          134/139
#   Verifying  : 1:cups-libs-1.6.3-35.el7.x86_64                          135/139
#   Verifying  : lcms2-2.6-3.el7.x86_64                                   136/139
#   Verifying  : augeas-libs-1.4.0-5.el7_5.1.x86_64                       137/139
#   Verifying  : libvirt-daemon-driver-storage-iscsi-3.9.0-14.el7_5.4.x   138/139
#   Verifying  : numad-0.5-18.20150602git.el7.x86_64                      139/139
#
# Installed:
#   libvirt.x86_64 0:3.9.0-14.el7_5.4    qemu-system-x86.x86_64 2:2.0.0-1.el7.6
#
# Dependency Installed:
#   adwaita-cursor-theme.noarch 0:3.26.0-1.el7
#   adwaita-icon-theme.noarch 0:3.26.0-1.el7
#   at-spi2-atk.x86_64 0:2.22.0-2.el7
#   at-spi2-core.x86_64 0:2.22.0-1.el7
#   atk.x86_64 0:2.22.0-3.el7
#   augeas-libs.x86_64 0:1.4.0-5.el7_5.1
#   autogen-libopts.x86_64 0:5.18-5.el7
#   bluez-libs.x86_64 0:5.44-4.el7_4
#   bridge-utils.x86_64 0:1.5-9.el7
#   brlapi.x86_64 0:0.6.0-16.el7
#   brltty.x86_64 0:4.5-16.el7
#   cairo.x86_64 0:1.14.8-2.el7
#   cairo-gobject.x86_64 0:1.14.8-2.el7
#   celt051.x86_64 0:0.5.1.3-8.el7
#   colord-libs.x86_64 0:1.3.4-1.el7
#   cups-libs.x86_64 1:1.6.3-35.el7
#   cyrus-sasl.x86_64 0:2.1.26-23.el7
#   cyrus-sasl-gssapi.x86_64 0:2.1.26-23.el7
#   dconf.x86_64 0:0.26.0-2.el7
#   dnsmasq.x86_64 0:2.76-5.el7
#   flac-libs.x86_64 0:1.3.0-5.el7_1
#   fuse-libs.x86_64 0:2.9.2-10.el7
#   gdk-pixbuf2.x86_64 0:2.36.5-1.el7
#   glib-networking.x86_64 0:2.50.0-1.el7
#   glusterfs.x86_64 0:3.8.4-53.el7.centos
#   glusterfs-api.x86_64 0:3.8.4-53.el7.centos
#   glusterfs-cli.x86_64 0:3.8.4-53.el7.centos
#   glusterfs-client-xlators.x86_64 0:3.8.4-53.el7.centos
#   glusterfs-libs.x86_64 0:3.8.4-53.el7.centos
#   gnutls-dane.x86_64 0:3.3.26-9.el7
#   gnutls-utils.x86_64 0:3.3.26-9.el7
#   gperftools-libs.x86_64 0:2.6.1-1.el7
#   graphite2.x86_64 0:1.3.10-1.el7_3
#   gsettings-desktop-schemas.x86_64 0:3.24.1-1.el7
#   gsm.x86_64 0:1.0.13-11.el7
#   gssproxy.x86_64 0:0.7.0-17.el7
#   gtk-update-icon-cache.x86_64 0:3.22.26-4.el7_5
#   gtk3.x86_64 0:3.22.26-4.el7_5
#   harfbuzz.x86_64 0:1.3.2-1.el7
#   hicolor-icon-theme.noarch 0:0.12-7.el7
#   ipxe-roms-qemu.noarch 0:20170123-1.git4e85b27.el7_4.1
#   iscsi-initiator-utils.x86_64 0:6.2.0.874-7.el7
#   iscsi-initiator-utils-iscsiuio.x86_64 0:6.2.0.874-7.el7
#   jasper-libs.x86_64 0:1.900.1-31.el7
#   jbigkit-libs.x86_64 0:2.0-11.el7
#   json-glib.x86_64 0:1.2.6-1.el7
#   keyutils.x86_64 0:1.5.8-3.el7
#   lcms2.x86_64 0:2.6-3.el7
#   libXcomposite.x86_64 0:0.4.4-4.1.el7
#   libXft.x86_64 0:2.3.2-2.el7
#   libXi.x86_64 0:1.7.9-1.el7
#   libXrandr.x86_64 0:1.5.1-2.el7
#   libXtst.x86_64 0:1.2.3-1.el7
#   libasyncns.x86_64 0:0.8-7.el7
#   libbasicobjects.x86_64 0:0.1.1-29.el7
#   libcgroup.x86_64 0:0.41-15.el7
#   libcollection.x86_64 0:0.7.0-29.el7
#   libepoxy.x86_64 0:1.3.1-2.el7_5
#   libevent.x86_64 0:2.0.21-4.el7
#   libgusb.x86_64 0:0.2.9-1.el7
#   libibverbs.x86_64 0:15-7.el7_5
#   libicu.x86_64 0:50.1.2-15.el7
#   libini_config.x86_64 0:1.3.1-29.el7
#   libiscsi.x86_64 0:1.9.0-7.el7
#   libnfsidmap.x86_64 0:0.25-19.el7
#   libogg.x86_64 2:1.3.0-7.el7
#   libpath_utils.x86_64 0:0.2.1-29.el7
#   libpcap.x86_64 14:1.5.3-11.el7
#   librados2.x86_64 1:0.94.5-2.el7
#   librbd1.x86_64 1:0.94.5-2.el7
#   librdmacm.x86_64 0:15-7.el7_5
#   libref_array.x86_64 0:0.1.5-29.el7
#   libsndfile.x86_64 0:1.0.25-10.el7
#   libsoup.x86_64 0:2.56.0-6.el7
#   libthai.x86_64 0:0.1.14-9.el7
#   libtiff.x86_64 0:4.0.3-27.el7_3
#   libtirpc.x86_64 0:0.2.4-0.10.el7
#   libusbx.x86_64 0:1.0.21-1.el7
#   libverto-libevent.x86_64 0:0.2.5-4.el7
#   libvirt-client.x86_64 0:3.9.0-14.el7_5.4
#   libvirt-daemon.x86_64 0:3.9.0-14.el7_5.4
#   libvirt-daemon-config-network.x86_64 0:3.9.0-14.el7_5.4
#   libvirt-daemon-config-nwfilter.x86_64 0:3.9.0-14.el7_5.4
#   libvirt-daemon-driver-interface.x86_64 0:3.9.0-14.el7_5.4
#   libvirt-daemon-driver-lxc.x86_64 0:3.9.0-14.el7_5.4
#   libvirt-daemon-driver-network.x86_64 0:3.9.0-14.el7_5.4
#   libvirt-daemon-driver-nodedev.x86_64 0:3.9.0-14.el7_5.4
#   libvirt-daemon-driver-nwfilter.x86_64 0:3.9.0-14.el7_5.4
#   libvirt-daemon-driver-qemu.x86_64 0:3.9.0-14.el7_5.4
#   libvirt-daemon-driver-secret.x86_64 0:3.9.0-14.el7_5.4
#   libvirt-daemon-driver-storage.x86_64 0:3.9.0-14.el7_5.4
#   libvirt-daemon-driver-storage-core.x86_64 0:3.9.0-14.el7_5.4
#   libvirt-daemon-driver-storage-disk.x86_64 0:3.9.0-14.el7_5.4
#   libvirt-daemon-driver-storage-gluster.x86_64 0:3.9.0-14.el7_5.4
#   libvirt-daemon-driver-storage-iscsi.x86_64 0:3.9.0-14.el7_5.4
#   libvirt-daemon-driver-storage-logical.x86_64 0:3.9.0-14.el7_5.4
#   libvirt-daemon-driver-storage-mpath.x86_64 0:3.9.0-14.el7_5.4
#   libvirt-daemon-driver-storage-rbd.x86_64 0:3.9.0-14.el7_5.4
#   libvirt-daemon-driver-storage-scsi.x86_64 0:3.9.0-14.el7_5.4
#   libvirt-libs.x86_64 0:3.9.0-14.el7_5.4
#   libvorbis.x86_64 1:1.3.3-8.el7.1
#   libwayland-client.x86_64 0:1.14.0-2.el7
#   libwayland-cursor.x86_64 0:1.14.0-2.el7
#   libwayland-server.x86_64 0:1.14.0-2.el7
#   libxkbcommon.x86_64 0:0.7.1-1.el7
#   lzop.x86_64 0:1.03-10.el7
#   mesa-libEGL.x86_64 0:17.2.3-8.20171019.el7
#   mesa-libgbm.x86_64 0:17.2.3-8.20171019.el7
#   mesa-libwayland-egl.x86_64 0:17.2.3-8.20171019.el7
#   netcf-libs.x86_64 0:0.2.8-4.el7
#   nfs-utils.x86_64 1:1.3.0-0.54.el7
#   nmap-ncat.x86_64 2:6.40-13.el7
#   numad.x86_64 0:0.5-18.20150602git.el7
#   opus.x86_64 0:1.0.2-6.el7
#   pango.x86_64 0:1.40.4-1.el7
#   pciutils.x86_64 0:3.5.1-3.el7
#   pixman.x86_64 0:0.34.0-1.el7
#   pulseaudio-libs.x86_64 0:10.0-5.el7
#   qemu-common.x86_64 2:2.0.0-1.el7.6
#   qemu-img.x86_64 10:1.5.3-156.el7_5.1
#   qemu-kvm-common.x86_64 10:1.5.3-156.el7_5.1
#   quota.x86_64 1:4.01-17.el7
#   quota-nls.noarch 1:4.01-17.el7
#   radvd.x86_64 0:1.9.2-9.el7_5.4
#   rdma-core.x86_64 0:15-7.el7_5
#   rest.x86_64 0:0.8.0-2.el7
#   rpcbind.x86_64 0:0.2.0-44.el7
#   seavgabios-bin.noarch 0:1.11.0-2.el7
#   sgabios-bin.noarch 1:0.20110622svn-4.el7
#   spice-server.x86_64 0:0.14.0-2.el7_5.3
#   tcp_wrappers.x86_64 0:7.6-77.el7
#   unbound-libs.x86_64 0:1.6.6-1.el7
#   usbredir.x86_64 0:0.7.1-3.el7
#   vte-profile.x86_64 0:0.46.2-1.el7
#   vte3.x86_64 0:0.36.5-1.el7
#   xkeyboard-config.noarch 0:2.20-1.el7
#   yajl.x86_64 0:2.0.4-4.el7
#
# Complete!

# %%
sudo wget http://download.virtualbox.org/virtualbox/rpm/el/virtualbox.repo

# %%
sudo mv virtualbox.repo  /etc/yum.repos.d/

# %%
sudo yum update -y

# %%
sudo yum install VirtualBox-5.2 -y

# %%
sudo /sbin/vboxconfig

# %%
wget https://download.virtualbox.org/virtualbox/5.2.12/Oracle_VM_VirtualBox_Extension_Pack-5.2.12.vbox-extpack

# %% [markdown]
# ``` sudo VBoxManage extpack install Oracle_VM_VirtualBox_Extension_Pack-5.2.12.vbox-extpack```

# %% [markdown]
# ## Vagrant.

# %%
sudo yum install https://releases.hashicorp.com/vagrant/2.1.1/vagrant_2.1.1_x86_64.rpm -y

# %% [markdown]
# ### Vagrant boxes.
#
# https://app.vagrantup.com/boxes/search

# %%
vagrant init

# %%
vagrant up

# %% [markdown]
# https://github.com/hashicorp/vagrant/wiki/Available-Vagrant-Plugins
